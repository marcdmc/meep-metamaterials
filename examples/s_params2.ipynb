# %% [markdown]
# # Split ring resonators
# From _Magnetic Response of Metamaterials at 100 Terahertz_

# %%
import meep as mp
import numpy as np
import matplotlib.pyplot as plt

resolution = 60  # pixels/um

pol = mp.Ey # Incident polarization

# Dimensions in um
l = .320
w = .090
a = .450 # Lattice constant
gap = .070

t = .020 # Thickness in um

# Dimensions of the cell
sep = a - l # Sepparation between resonators
width = l + sep
height = l + sep

st = 10*a # Substrate thickness
depth = 2*st

cell = mp.Vector3(a, a, depth) # 3D cell

# PML layers
dpml = 2 # Width of the PML
pml = mp.PML(dpml, direction=mp.Z) # PML in the non-periodic direction

# Wavelengths in um
wmin = 1.5 # minimum wavelength
wmax = 5 # maximum wavelength
wcen = (wmax-wmin)/2 + wmin # central wavelength

fmin = 1/wmax # minimum frequency
fmax = 1/wmin # maximum frequency
fcen = (fmax-fmin)/2 + fmin # central frequency
nfreqs = 100 # number of frequencies calculated

sources = [
    mp.Source(mp.GaussianSource(fcen, fwidth=fmax-fmin),
              component=pol,
              center=mp.Vector3(0,0,-depth/2+dpml),
              size=mp.Vector3(a, a, 0)),
]

# symmetries = [mp.Mirror(mp.Y)]

# %%
refl_fr = mp.ModeRegion(center=mp.Vector3(0,0,-depth/2+dpml+0.2), size=mp.Vector3(width, height, 0))
tran_fr = mp.ModeRegion(center=mp.Vector3(0,0,depth/2-dpml-0.1), size=mp.Vector3(width, height, 0))

# %%
c_ = 299792458
wp = 2.175e15/(c_*1e6) # Plasma frequency
gamma = 6.5e12/(c_*1e6) # Collision frequency
susc = mp.DrudeSusceptibility(frequency=wp, gamma=gamma*1.65, sigma=1)

Gold = mp.Medium(epsilon=1, E_susceptibilities=[susc])

# %%
gamma
# Out:
# 0.021681666187879884

# %%
from meep.materials import Au, SiO2

n_SiO2 = 1.4059

# substrate = SiO2
metal = Gold
# substrate = mp.Medium(index=n_SiO2)

# Define the geometry
geometry = [
    # mp.Block(size=mp.Vector3(mp.inf, mp.inf, depth/2), center=mp.Vector3(0,0,depth/4), material=substrate),
    mp.Block(size=mp.Vector3(t, w, l), center=mp.Vector3(0, l/2-w/2, 0), material=metal),
    mp.Block(size=mp.Vector3(t, w, l), center=mp.Vector3(0, -l/2+w/2, 0), material=metal),
    mp.Block(size=mp.Vector3(t, l, w), center=mp.Vector3(0, 0, l/2-w/2), material=metal),
    mp.Block(size=mp.Vector3(t, l, w), center=mp.Vector3(0, 0, -l/2+w/2), material=metal),
    mp.Block(size=mp.Vector3(t, w, gap), center=mp.Vector3(0, l/2-w/2, 0), material=mp.Medium(epsilon=1)), # Gap
]

sim = mp.Simulation(
    cell_size=cell,
    boundary_layers=[pml],
    geometry=geometry,
    k_point=mp.Vector3(0,0,0), # Periodicity
    sources=sources,
    # symmetries=symmetries,
    resolution=resolution)

refl = sim.add_mode_monitor(fcen, fmax-fmin, nfreqs, refl_fr)
tran = sim.add_mode_monitor(fcen, fmax-fmin, nfreqs, tran_fr)

# %%
refl = sim.add_mode_monitor(fcen, fmax-fmin, nfreqs, refl_fr)
tran = sim.add_mode_monitor(fcen, fmax-fmin, nfreqs, tran_fr)

freqs = mp.get_flux_freqs(refl)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00803995 s
# Working in 3D dimensions.
# Computational cell is 0.45 x 0.45 x 9 with resolution 60
#      block, center = (0,0.115,0)
#           size (0.02,0.09,0.32)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.115,0)
#           size (0.02,0.09,0.32)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,0.115)
#           size (0.02,0.32,0.09)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-0.115)
#           size (0.02,0.32,0.09)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0.115,0)
#           size (0.02,0.09,0.07)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 2.05626 s
# drude susceptibility: frequency=7.25502, gamma=0.0357747
# -----------

# %%
sim.plot2D(output_plane=mp.Volume(size=mp.Vector3(0, a, depth), center=mp.Vector3(0,0,0)))
# Out:
#      block, center = (0,0.115,0)
#           size (0.02,0.09,0.32)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.115,0)
#           size (0.02,0.09,0.32)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,0.115)
#           size (0.02,0.32,0.09)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-0.115)
#           size (0.02,0.32,0.09)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0.115,0)
#           size (0.02,0.09,0.07)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# <AxesSubplot:xlabel='Y', ylabel='Z'>

# %%
# from playsound import playsound

pt = mp.Vector3(0,0,depth/2-dpml-0.1)
sim.run(until_after_sources=mp.stop_when_fields_decayed(50,pol,pt,0.001))

# playsound('alarm.mp3')

refl_flux = mp.get_fluxes(refl)
tran_flux = mp.get_fluxes(tran)
# Out:
# on time step 93 (time=0.775), 0.0433885 s/step
# on time step 291 (time=2.425), 0.0202378 s/step
# on time step 504 (time=4.2), 0.0188738 s/step
# on time step 705 (time=5.875), 0.0199323 s/step
# on time step 906 (time=7.55), 0.0199113 s/step
# on time step 1103 (time=9.19167), 0.0203342 s/step
# on time step 1323 (time=11.025), 0.0181821 s/step
# on time step 1544 (time=12.8667), 0.0181139 s/step
# on time step 1741 (time=14.5083), 0.0203101 s/step
# on time step 1950 (time=16.25), 0.0192535 s/step
# on time step 2162 (time=18.0167), 0.0189004 s/step
# on time step 2350 (time=19.5833), 0.0213872 s/step
# on time step 2538 (time=21.15), 0.021406 s/step
# on time step 2715 (time=22.625), 0.0226918 s/step
# on time step 2876 (time=23.9667), 0.0249366 s/step
# on time step 3074 (time=25.6167), 0.0203046 s/step
# on time step 3271 (time=27.2583), 0.0203613 s/step
# on time step 3467 (time=28.8917), 0.0204736 s/step
# on time step 3666 (time=30.55), 0.0201812 s/step
# on time step 3867 (time=32.225), 0.0199723 s/step
# on time step 4068 (time=33.9), 0.0199724 s/step
# on time step 4273 (time=35.6083), 0.0195329 s/step
# on time step 4476 (time=37.3), 0.0197494 s/step
# on time step 4680 (time=39), 0.0196501 s/step
# on time step 4881 (time=40.675), 0.0200259 s/step
# on time step 5065 (time=42.2083), 0.0218246 s/step
# on time step 5246 (time=43.7167), 0.0221674 s/step
# on time step 5429 (time=45.2417), 0.0219509 s/step
# on time step 5613 (time=46.775), 0.0217757 s/step
# on time step 5778 (time=48.15), 0.0243402 s/step
# on time step 5959 (time=49.6583), 0.0222016 s/step
# field decay(t = 50.00833333333333): 0.14517970440800423 / 0.14517970440800423 = 1.0
# on time step 6132 (time=51.1), 0.0231458 s/step
# on time step 6307 (time=52.5583), 0.0229433 s/step
# on time step 6480 (time=54), 0.0231883 s/step
# on time step 6657 (time=55.475), 0.0226754 s/step
# on time step 6832 (time=56.9333), 0.0228877 s/step
# on time step 7036 (time=58.6333), 0.019679 s/step
# on time step 7237 (time=60.3083), 0.0199708 s/step
# on time step 7419 (time=61.825), 0.0220402 s/step
# on time step 7610 (time=63.4167), 0.0210346 s/step
# on time step 7798 (time=64.9833), 0.0213172 s/step
# on time step 7994 (time=66.6167), 0.0204268 s/step
# on time step 8177 (time=68.1417), 0.0219274 s/step
# on time step 8374 (time=69.7833), 0.0203508 s/step
# on time step 8560 (time=71.3333), 0.0215508 s/step
# on time step 8756 (time=72.9667), 0.0204171 s/step
# on time step 8954 (time=74.6167), 0.0202331 s/step
# on time step 9154 (time=76.2833), 0.0200278 s/step
# on time step 9357 (time=77.975), 0.0197163 s/step
# on time step 9488 (time=79.0667), 0.0305465 s/step
# on time step 9620 (time=80.1667), 0.0304407 s/step
# on time step 9778 (time=81.4833), 0.0254968 s/step
# on time step 9945 (time=82.875), 0.0240412 s/step
# on time step 10085 (time=84.0417), 0.028595 s/step
# on time step 10259 (time=85.4917), 0.0230895 s/step
# on time step 10433 (time=86.9417), 0.0229966 s/step
# on time step 10612 (time=88.4333), 0.0224509 s/step
# on time step 10805 (time=90.0417), 0.0207443 s/step
# on time step 11008 (time=91.7333), 0.0197285 s/step
# on time step 11143 (time=92.8583), 0.0297647 s/step
# on time step 11229 (time=93.575), 0.0471824 s/step
# on time step 11347 (time=94.5583), 0.0339604 s/step
# on time step 11448 (time=95.4), 0.0399366 s/step
# on time step 11571 (time=96.425), 0.0326236 s/step
# on time step 11692 (time=97.4333), 0.0332881 s/step
# on time step 11787 (time=98.225), 0.0422053 s/step
# on time step 11900 (time=99.1667), 0.0356257 s/step
# field decay(t = 100.01666666666667): 5.411938687440767e-06 / 0.14517970440800423 = 3.727751554192026e-05
# run 0 finished at t = 100.01666666666667 (12002 timesteps)

# %%
sim.plot2D(output_plane=mp.Volume(size=mp.Vector3(0, a, depth), center=mp.Vector3(0,0,0)), fields=pol)
# Out:
#      block, center = (0,0.115,0)
#           size (0.02,0.09,0.32)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-0.115,0)
#           size (0.02,0.09,0.32)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,0.115)
#           size (0.02,0.32,0.09)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-0.115)
#           size (0.02,0.32,0.09)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0.115,0)
#           size (0.02,0.09,0.07)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# <AxesSubplot:xlabel='Y', ylabel='Z'>

# %%
wl = []
for i in range(nfreqs):
    wl = np.append(wl, 1/freqs[i])

# %% [markdown]
# ---
# #### S parameters

# %%
S11 = sim.get_eigenmode_coefficients(refl, [1]).alpha[0]
S21 = sim.get_eigenmode_coefficients(tran, [1]).alpha[0]
# Out:
# MPB solved for frequency_1(0,0,0.2) = 0.2 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.200000)
# MPB solved for frequency_1(0,0,0.204714) = 0.204714 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.204714)
# MPB solved for frequency_1(0,0,0.209428) = 0.209428 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.209428)
# MPB solved for frequency_1(0,0,0.214141) = 0.214141 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.214141)
# MPB solved for frequency_1(0,0,0.218855) = 0.218855 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.218855)
# MPB solved for frequency_1(0,0,0.223569) = 0.223569 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.223569)
# MPB solved for frequency_1(0,0,0.228283) = 0.228283 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.228283)
# MPB solved for frequency_1(0,0,0.232997) = 0.232997 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.232997)
# MPB solved for frequency_1(0,0,0.23771) = 0.23771 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.237710)
# MPB solved for frequency_1(0,0,0.242424) = 0.242424 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.242424)
# MPB solved for frequency_1(0,0,0.247138) = 0.247138 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.247138)
# MPB solved for frequency_1(0,0,0.251852) = 0.251852 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.251852)
# MPB solved for frequency_1(0,0,0.256566) = 0.256566 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.256566)
# MPB solved for frequency_1(0,0,0.261279) = 0.261279 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.261279)
# MPB solved for frequency_1(0,0,0.265993) = 0.265993 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.265993)
# MPB solved for frequency_1(0,0,0.270707) = 0.270707 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.270707)
# MPB solved for frequency_1(0,0,0.275421) = 0.275421 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.275421)
# MPB solved for frequency_1(0,0,0.280135) = 0.280135 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.280135)
# MPB solved for frequency_1(0,0,0.284848) = 0.284848 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.284848)
# MPB solved for frequency_1(0,0,0.289562) = 0.289562 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.289562)
# MPB solved for frequency_1(0,0,0.294276) = 0.294276 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.294276)
# MPB solved for frequency_1(0,0,0.29899) = 0.29899 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.298990)
# MPB solved for frequency_1(0,0,0.303704) = 0.303704 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.303704)
# MPB solved for frequency_1(0,0,0.308418) = 0.308418 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.308418)
# MPB solved for frequency_1(0,0,0.313131) = 0.313131 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.313131)
# MPB solved for frequency_1(0,0,0.317845) = 0.317845 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.317845)
# MPB solved for frequency_1(0,0,0.322559) = 0.322559 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.322559)
# MPB solved for frequency_1(0,0,0.327273) = 0.327273 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.327273)
# MPB solved for frequency_1(0,0,0.331987) = 0.331987 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.331987)
# MPB solved for frequency_1(0,0,0.3367) = 0.3367 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.336700)
# MPB solved for frequency_1(0,0,0.341414) = 0.341414 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.341414)
# MPB solved for frequency_1(0,0,0.346128) = 0.346128 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.346128)
# MPB solved for frequency_1(0,0,0.350842) = 0.350842 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.350842)
# MPB solved for frequency_1(0,0,0.355556) = 0.355556 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.355556)
# MPB solved for frequency_1(0,0,0.360269) = 0.360269 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.360269)
# MPB solved for frequency_1(0,0,0.364983) = 0.364983 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.364983)
# MPB solved for frequency_1(0,0,0.369697) = 0.369697 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.369697)
# MPB solved for frequency_1(0,0,0.374411) = 0.374411 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.374411)
# MPB solved for frequency_1(0,0,0.379125) = 0.379125 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.379125)
# MPB solved for frequency_1(0,0,0.383838) = 0.383838 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.383838)
# MPB solved for frequency_1(0,0,0.388552) = 0.388552 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.388552)
# MPB solved for frequency_1(0,0,0.393266) = 0.393266 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.393266)
# MPB solved for frequency_1(0,0,0.39798) = 0.39798 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.397980)
# MPB solved for frequency_1(0,0,0.402694) = 0.402694 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.402694)
# MPB solved for frequency_1(0,0,0.407407) = 0.407407 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.407407)
# MPB solved for frequency_1(0,0,0.412121) = 0.412121 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.412121)
# MPB solved for frequency_1(0,0,0.416835) = 0.416835 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.416835)
# MPB solved for frequency_1(0,0,0.421549) = 0.421549 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.421549)
# MPB solved for frequency_1(0,0,0.426263) = 0.426263 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.426263)
# MPB solved for frequency_1(0,0,0.430976) = 0.430976 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.430976)
# MPB solved for frequency_1(0,0,0.43569) = 0.43569 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.435690)
# MPB solved for frequency_1(0,0,0.440404) = 0.440404 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.440404)
# MPB solved for frequency_1(0,0,0.445118) = 0.445118 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.445118)
# MPB solved for frequency_1(0,0,0.449832) = 0.449832 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.449832)
# MPB solved for frequency_1(0,0,0.454545) = 0.454545 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.454545)
# MPB solved for frequency_1(0,0,0.459259) = 0.459259 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.459259)
# MPB solved for frequency_1(0,0,0.463973) = 0.463973 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.463973)
# MPB solved for frequency_1(0,0,0.468687) = 0.468687 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.468687)
# MPB solved for frequency_1(0,0,0.473401) = 0.473401 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.473401)
# MPB solved for frequency_1(0,0,0.478114) = 0.478114 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.478114)
# MPB solved for frequency_1(0,0,0.482828) = 0.482828 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.482828)
# MPB solved for frequency_1(0,0,0.487542) = 0.487542 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.487542)
# MPB solved for frequency_1(0,0,0.492256) = 0.492256 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.492256)
# MPB solved for frequency_1(0,0,0.49697) = 0.49697 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.496970)
# MPB solved for frequency_1(0,0,0.501684) = 0.501684 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.501684)
# MPB solved for frequency_1(0,0,0.506397) = 0.506397 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.506397)
# MPB solved for frequency_1(0,0,0.511111) = 0.511111 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.511111)
# MPB solved for frequency_1(0,0,0.515825) = 0.515825 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.515825)
# MPB solved for frequency_1(0,0,0.520539) = 0.520539 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.520539)
# MPB solved for frequency_1(0,0,0.525253) = 0.525253 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.525253)
# MPB solved for frequency_1(0,0,0.529966) = 0.529966 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.529966)
# MPB solved for frequency_1(0,0,0.53468) = 0.53468 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.534680)
# MPB solved for frequency_1(0,0,0.539394) = 0.539394 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.539394)
# MPB solved for frequency_1(0,0,0.544108) = 0.544108 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.544108)
# MPB solved for frequency_1(0,0,0.548822) = 0.548822 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.548822)
# MPB solved for frequency_1(0,0,0.553535) = 0.553535 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.553535)
# MPB solved for frequency_1(0,0,0.558249) = 0.558249 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.558249)
# MPB solved for frequency_1(0,0,0.562963) = 0.562963 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.562963)
# MPB solved for frequency_1(0,0,0.567677) = 0.567677 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.567677)
# MPB solved for frequency_1(0,0,0.572391) = 0.572391 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.572391)
# MPB solved for frequency_1(0,0,0.577104) = 0.577104 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.577104)
# MPB solved for frequency_1(0,0,0.581818) = 0.581818 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.581818)
# MPB solved for frequency_1(0,0,0.586532) = 0.586532 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.586532)
# MPB solved for frequency_1(0,0,0.591246) = 0.591246 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.591246)
# MPB solved for frequency_1(0,0,0.59596) = 0.59596 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.595960)
# MPB solved for frequency_1(0,0,0.600673) = 0.600673 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.600673)
# MPB solved for frequency_1(0,0,0.605387) = 0.605387 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.605387)
# MPB solved for frequency_1(0,0,0.610101) = 0.610101 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.610101)
# MPB solved for frequency_1(0,0,0.614815) = 0.614815 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.614815)
# MPB solved for frequency_1(0,0,0.619529) = 0.619529 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.619529)
# MPB solved for frequency_1(0,0,0.624242) = 0.624242 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.624242)
# MPB solved for frequency_1(0,0,0.628956) = 0.628956 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.628956)
# MPB solved for frequency_1(0,0,0.63367) = 0.63367 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.633670)
# MPB solved for frequency_1(0,0,0.638384) = 0.638384 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.638384)
# MPB solved for frequency_1(0,0,0.643098) = 0.643098 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.643098)
# MPB solved for frequency_1(0,0,0.647811) = 0.647811 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.647811)
# MPB solved for frequency_1(0,0,0.652525) = 0.652525 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.652525)
# MPB solved for frequency_1(0,0,0.657239) = 0.657239 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.657239)
# MPB solved for frequency_1(0,0,0.661953) = 0.661953 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.661953)
# MPB solved for frequency_1(0,0,0.666667) = 0.666667 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.666667)
# MPB solved for frequency_1(0,0,0.2) = 0.2 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.200000)
# MPB solved for frequency_1(0,0,0.204714) = 0.204714 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.204714)
# MPB solved for frequency_1(0,0,0.209428) = 0.209428 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.209428)
# MPB solved for frequency_1(0,0,0.214141) = 0.214141 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.214141)
# MPB solved for frequency_1(0,0,0.218855) = 0.218855 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.218855)
# MPB solved for frequency_1(0,0,0.223569) = 0.223569 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.223569)
# MPB solved for frequency_1(0,0,0.228283) = 0.228283 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.228283)
# MPB solved for frequency_1(0,0,0.232997) = 0.232997 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.232997)
# MPB solved for frequency_1(0,0,0.23771) = 0.23771 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.237710)
# MPB solved for frequency_1(0,0,0.242424) = 0.242424 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.242424)
# MPB solved for frequency_1(0,0,0.247138) = 0.247138 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.247138)
# MPB solved for frequency_1(0,0,0.251852) = 0.251852 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.251852)
# MPB solved for frequency_1(0,0,0.256566) = 0.256566 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.256566)
# MPB solved for frequency_1(0,0,0.261279) = 0.261279 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.261279)
# MPB solved for frequency_1(0,0,0.265993) = 0.265993 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.265993)
# MPB solved for frequency_1(0,0,0.270707) = 0.270707 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.270707)
# MPB solved for frequency_1(0,0,0.275421) = 0.275421 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.275421)
# MPB solved for frequency_1(0,0,0.280135) = 0.280135 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.280135)
# MPB solved for frequency_1(0,0,0.284848) = 0.284848 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.284848)
# MPB solved for frequency_1(0,0,0.289562) = 0.289562 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.289562)
# MPB solved for frequency_1(0,0,0.294276) = 0.294276 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.294276)
# MPB solved for frequency_1(0,0,0.29899) = 0.29899 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.298990)
# MPB solved for frequency_1(0,0,0.303704) = 0.303704 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.303704)
# MPB solved for frequency_1(0,0,0.308418) = 0.308418 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.308418)
# MPB solved for frequency_1(0,0,0.313131) = 0.313131 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.313131)
# MPB solved for frequency_1(0,0,0.317845) = 0.317845 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.317845)
# MPB solved for frequency_1(0,0,0.322559) = 0.322559 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.322559)
# MPB solved for frequency_1(0,0,0.327273) = 0.327273 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.327273)
# MPB solved for frequency_1(0,0,0.331987) = 0.331987 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.331987)
# MPB solved for frequency_1(0,0,0.3367) = 0.3367 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.336700)
# MPB solved for frequency_1(0,0,0.341414) = 0.341414 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.341414)
# MPB solved for frequency_1(0,0,0.346128) = 0.346128 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.346128)
# MPB solved for frequency_1(0,0,0.350842) = 0.350842 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.350842)
# MPB solved for frequency_1(0,0,0.355556) = 0.355556 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.355556)
# MPB solved for frequency_1(0,0,0.360269) = 0.360269 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.360269)
# MPB solved for frequency_1(0,0,0.364983) = 0.364983 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.364983)
# MPB solved for frequency_1(0,0,0.369697) = 0.369697 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.369697)
# MPB solved for frequency_1(0,0,0.374411) = 0.374411 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.374411)
# MPB solved for frequency_1(0,0,0.379125) = 0.379125 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.379125)
# MPB solved for frequency_1(0,0,0.383838) = 0.383838 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.383838)
# MPB solved for frequency_1(0,0,0.388552) = 0.388552 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.388552)
# MPB solved for frequency_1(0,0,0.393266) = 0.393266 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.393266)
# MPB solved for frequency_1(0,0,0.39798) = 0.39798 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.397980)
# MPB solved for frequency_1(0,0,0.402694) = 0.402694 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.402694)
# MPB solved for frequency_1(0,0,0.407407) = 0.407407 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.407407)
# MPB solved for frequency_1(0,0,0.412121) = 0.412121 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.412121)
# MPB solved for frequency_1(0,0,0.416835) = 0.416835 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.416835)
# MPB solved for frequency_1(0,0,0.421549) = 0.421549 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.421549)
# MPB solved for frequency_1(0,0,0.426263) = 0.426263 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.426263)
# MPB solved for frequency_1(0,0,0.430976) = 0.430976 after 5 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.430976)
# MPB solved for frequency_1(0,0,0.43569) = 0.43569 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.435690)
# MPB solved for frequency_1(0,0,0.440404) = 0.440404 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.440404)
# MPB solved for frequency_1(0,0,0.445118) = 0.445118 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.445118)
# MPB solved for frequency_1(0,0,0.449832) = 0.449832 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.449832)
# MPB solved for frequency_1(0,0,0.454545) = 0.454545 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.454545)
# MPB solved for frequency_1(0,0,0.459259) = 0.459259 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.459259)
# MPB solved for frequency_1(0,0,0.463973) = 0.463973 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.463973)
# MPB solved for frequency_1(0,0,0.468687) = 0.468687 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.468687)
# MPB solved for frequency_1(0,0,0.473401) = 0.473401 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.473401)
# MPB solved for frequency_1(0,0,0.478114) = 0.478114 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.478114)
# MPB solved for frequency_1(0,0,0.482828) = 0.482828 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.482828)
# MPB solved for frequency_1(0,0,0.487542) = 0.487542 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.487542)
# MPB solved for frequency_1(0,0,0.492256) = 0.492256 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.492256)
# MPB solved for frequency_1(0,0,0.49697) = 0.49697 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.496970)
# MPB solved for frequency_1(0,0,0.501684) = 0.501684 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.501684)
# MPB solved for frequency_1(0,0,0.506397) = 0.506397 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.506397)
# MPB solved for frequency_1(0,0,0.511111) = 0.511111 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.511111)
# MPB solved for frequency_1(0,0,0.515825) = 0.515825 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.515825)
# MPB solved for frequency_1(0,0,0.520539) = 0.520539 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.520539)
# MPB solved for frequency_1(0,0,0.525253) = 0.525253 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.525253)
# MPB solved for frequency_1(0,0,0.529966) = 0.529966 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.529966)
# MPB solved for frequency_1(0,0,0.53468) = 0.53468 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.534680)
# MPB solved for frequency_1(0,0,0.539394) = 0.539394 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.539394)
# MPB solved for frequency_1(0,0,0.544108) = 0.544108 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.544108)
# MPB solved for frequency_1(0,0,0.548822) = 0.548822 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.548822)
# MPB solved for frequency_1(0,0,0.553535) = 0.553535 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.553535)
# MPB solved for frequency_1(0,0,0.558249) = 0.558249 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.558249)
# MPB solved for frequency_1(0,0,0.562963) = 0.562963 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.562963)
# MPB solved for frequency_1(0,0,0.567677) = 0.567677 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.567677)
# MPB solved for frequency_1(0,0,0.572391) = 0.572391 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.572391)
# MPB solved for frequency_1(0,0,0.577104) = 0.577104 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.577104)
# MPB solved for frequency_1(0,0,0.581818) = 0.581818 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.581818)
# MPB solved for frequency_1(0,0,0.586532) = 0.586532 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.586532)
# MPB solved for frequency_1(0,0,0.591246) = 0.591246 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.591246)
# MPB solved for frequency_1(0,0,0.59596) = 0.59596 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.595960)
# MPB solved for frequency_1(0,0,0.600673) = 0.600673 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.600673)
# MPB solved for frequency_1(0,0,0.605387) = 0.605387 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.605387)
# MPB solved for frequency_1(0,0,0.610101) = 0.610101 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.610101)
# MPB solved for frequency_1(0,0,0.614815) = 0.614815 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.614815)
# MPB solved for frequency_1(0,0,0.619529) = 0.619529 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.619529)
# MPB solved for frequency_1(0,0,0.624242) = 0.624242 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.624242)
# MPB solved for frequency_1(0,0,0.628956) = 0.628956 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.628956)
# MPB solved for frequency_1(0,0,0.63367) = 0.63367 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.633670)
# MPB solved for frequency_1(0,0,0.638384) = 0.638384 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.638384)
# MPB solved for frequency_1(0,0,0.643098) = 0.643098 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.643098)
# MPB solved for frequency_1(0,0,0.647811) = 0.647811 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.647811)
# MPB solved for frequency_1(0,0,0.652525) = 0.652525 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.652525)
# MPB solved for frequency_1(0,0,0.657239) = 0.657239 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.657239)
# MPB solved for frequency_1(0,0,0.661953) = 0.661953 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.661953)
# MPB solved for frequency_1(0,0,0.666667) = 0.666667 after 6 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.666667)

# %%
a = np.array([coef[1] for coef in S11])
b = np.array([coef[0] for coef in S21])
c = np.array([coef[0] for coef in S11])

# %%
plt.plot(wl, np.abs(a/c)**2, label='$|S_{11}|^2$')
plt.plot(wl, np.abs(b/c)**2, label='$|S_{21}|^2$')
plt.legend()

# %% [markdown]
# Save S parameters to xlsx file

# %%
# Save S parameter data to xmls
import pandas as pd

f = np.array(freqs)
df = pd.DataFrame(data={'f': f, 'R': a/c, 'T': b/c, 'a': a, 'b': b, 'c': c})
df.to_excel('s_params_yy.xlsx')

# %% [markdown]
# ---

# %% [markdown]
# #### Retrieval

# %%
k = 2*np.pi/wl
prepad = st-dpml-0.2-l/2
postpad = st-dpml-0.1-l/2

# S11 = a/c * np.exp(-1j*k*(2*prepad+0.2))
# S21 = b/c * np.exp(-1j*k*(prepad+0.2)-1j*k*postpad)
S11 = a/c * np.exp(-1j*k*(2*prepad))
S21 = b/c * np.exp(-1j*k*(prepad)-1j*k*postpad)

# %%
# Save results in excel file
df = pd.DataFrame(data={'f': f, 'S11': S11, 'S21': S21})
df.to_excel('results/s_params_mag.xlsx')

# %%
def retrieve(S11, S21, branch=0):
    z = np.sqrt(((1+S11)**2-S21**2)/((1-S11)**2-S21**2))
    einkd = S21/(1-S11*(z-1)/(z+1))
    n = 1/(k*l) * ((np.imag(np.log(einkd))+2*np.pi*branch) - 1j*np.real(np.log(einkd)))

    eps = n/z
    mu = n*z

    return [eps, mu, n, z]

# %%
branch = 0

z = np.sqrt(((1+S11)**2-S21**2)/((1-S11)**2-S21**2))
einkd = S21/(1-S11*(z-1)/(z+1))
n = 1/(k*l) * ((np.imag(np.log(einkd))+2*np.pi*branch) - 1j*np.real(np.log(einkd)))

eps = n/z
mu = n*z

# %%
plt.plot(np.array(freqs)*c_/1e6, np.real(eps), label='$\epsilon$')
plt.plot(np.array(freqs)*c_/1e6, np.real(mu), label='$\mu$')
plt.plot(np.array(freqs)*c_/1e6, np.zeros(nfreqs), '--', color='black')
plt.legend()
plt.title('Magnetic coupling')
plt.xlabel('Frequency (THz)')
plt.ylabel('Permittivity, Permeability')
# plt.xlim(60, 150)
# plt.ylim(-2.5, 2.5)

# Save figure
import time
timestr = time.strftime("%Y%m%d-%H%M%S")
plt.savefig('results/s_params_mag'+timestr+'.png', dpi=300)
