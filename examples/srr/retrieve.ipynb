# %% [markdown]
# # SRR effective parameter retrieval

# %% [markdown]
# Comparison of double split ring resonators.

# %%
import meep as mp
import numpy as np
import matplotlib.pyplot as plt
import sys, os

from meep.materials import Ag

import os, sys
sys.path.append('../..')
from meep_metamaterials import metamaterials as mm
from meep_metamaterials.retrieval import retrieval

freq_range = np.linspace(0.3, 0.7, 50)
S11 = np.loadtxt('tmp/E/s11.txt', dtype=np.complex128)
S21 = np.loadtxt('tmp/E/s21.txt', dtype=np.complex128)
params = retrieval.eff_parameters(freq_range, 0.02, S11, S21)

# %%
from turtle import width


plt.figure()
plt.plot(freq_range*3e8*1e6/1e12, np.abs(S11)**2, 'b', label='S11')
plt.plot(freq_range*3e8*1e6/1e12, np.abs(S21)**2, 'r', label='S21')
plt.grid()
plt.legend()
plt.xlabel('Frequency (THz)')

plt.figure()
plt.plot(freq_range*3e8*1e6/1e12, np.real(params['eps']), 'b', label='Re($\epsilon$)')
plt.plot(freq_range*3e8*1e6/1e12, 10*np.real(params['mu']), 'r', label='10 $\cdot$ Re($\mu$)')
plt.grid()
plt.legend()
plt.xlabel('Frequency (THz)')

plt.figure()
plt.plot(freq_range*3e8*1e6/1e12, np.real(params['eps']), 'b', label='Re($\epsilon$)')
plt.plot(freq_range*3e8*1e6/1e12, np.real(params['mu']), 'r', label='Re($\mu$)')
plt.grid()
plt.legend()
plt.xlabel('Frequency (THz)')
# Out:
# Text(0.5, 0, 'Frequency (THz)')

# %%
1/2.3*3e8*1e6/1e12
# Out:
# 130.43478260869568

# %%
s11_1 = np.loadtxt('tmp/E/double_layer1_s11.txt', dtype=np.complex128)
s21_1 = np.loadtxt('tmp/E/double_layer1_s21.txt', dtype=np.complex128)

s11_2 = np.loadtxt('tmp/E/double_layer2_s11.txt', dtype=np.complex128)
s21_2 = np.loadtxt('tmp/E/double_layer2_s21.txt', dtype=np.complex128)

freq_range = np.linspace(0.3, 0.7, 50)
params_1 = retrieval.eff_parameters(freq_range, 0.07, s11_1, s21_1, plot_branches=True)
params_2 = retrieval.eff_parameters(freq_range, 0.52, s11_2, s21_2, continuity=True, plot_branches=True, branch=0, th=100)

# %%
plt.plot(freq_range*3e8*1e6/1e12, np.real(params_1['eps']), 'b')
plt.plot(freq_range*3e8*1e6/1e12, np.real(params_1['mu']), 'r')

plt.plot(freq_range*3e8*1e6/1e12, np.real(params_2['eps']), 'b', linestyle='--')
plt.plot(freq_range*3e8*1e6/1e12, np.real(params_2['mu']), 'r', linestyle='--')

plt.plot([], [], 'k', label='1 double layer')
plt.plot([], [], 'k', linestyle='--', label='2 double layers')
plt.plot([],[],'b', label='Re($\epsilon$)')
plt.plot([],[],'r', label='Re($\mu$)')
plt.xlabel('Frequency (THz)')
plt.grid()
plt.legend()
plt.title("Stacked SRRs with 1 and 2 layers")
# Out:
# Text(0.5, 1.0, 'Stacked SRRs with 1 and 2 layers')

# %%
# Comparison with normal case
plt.plot(freq_range*3e8*1e6/1e12, np.real(params_1['eps']), 'b')
plt.plot(freq_range*3e8*1e6/1e12, 10*np.real(params_1['mu']), 'r')

plt.plot(freq_range*3e8*1e6/1e12, np.real(params['eps']), 'b', linestyle='--')
plt.plot(freq_range*3e8*1e6/1e12, np.real(params['mu']), 'r', linestyle='--')

plt.plot([], [], 'k', label='1 double layer')
plt.plot([], [], 'k', linestyle='--', label='Single layer')
plt.plot([],[],'b', label='Re($\epsilon$)')
plt.plot([],[],'r', label='Re($\mu$)')
plt.xlabel('Frequency (THz)')
plt.grid()
plt.legend()
plt.title("Single and double layer SRRs")
# Out:
# Text(0.5, 1.0, 'Single and double layer SRRs')

# %% [markdown]
# ---
# Different separations of two layers (done right)

# %%
import meep as mp
import numpy as np
import matplotlib.pyplot as plt
import sys, os

from meep.materials import Ag

import os, sys
sys.path.append('../..')
from meep_metamaterials import metamaterials as mm
from meep_metamaterials.retrieval import retrieval

# %%
s11_1 = np.loadtxt('tmp/E/S11_2_11.txt', dtype=np.complex128)
s21_1 = np.loadtxt('tmp/E/S21_2_11.txt', dtype=np.complex128)

s11_2 = np.loadtxt('tmp/E/S11_2_12.txt', dtype=np.complex128)
s21_2 = np.loadtxt('tmp/E/S21_2_12.txt', dtype=np.complex128)

s11_3 = np.loadtxt('tmp/E/S11_2_13.txt', dtype=np.complex128)
s21_3 = np.loadtxt('tmp/E/S21_2_13.txt', dtype=np.complex128)

s11_4 = np.loadtxt('tmp/E/S11_2_14.txt', dtype=np.complex128)
s21_4 = np.loadtxt('tmp/E/S21_2_14.txt', dtype=np.complex128)

s11_5 = np.loadtxt('tmp/E/S11_2_15.txt', dtype=np.complex128)
s21_5 = np.loadtxt('tmp/E/S21_2_15.txt', dtype=np.complex128)

s11_6 = np.loadtxt('tmp/E/S11_2_16.txt', dtype=np.complex128)
s21_6 = np.loadtxt('tmp/E/S21_2_16.txt', dtype=np.complex128)

s11_7 = np.loadtxt('tmp/E/S11_2_17.txt', dtype=np.complex128)
s21_7 = np.loadtxt('tmp/E/S21_2_17.txt', dtype=np.complex128)

s11_8 = np.loadtxt('tmp/E/S11_2_18.txt', dtype=np.complex128)
s21_8 = np.loadtxt('tmp/E/S21_2_18.txt', dtype=np.complex128)

s11_9 = np.loadtxt('tmp/E/S11_2_19.txt', dtype=np.complex128)
s21_9 = np.loadtxt('tmp/E/S21_2_19.txt', dtype=np.complex128)

freq_range = np.linspace(0.3, 0.7, 50)
sep = np.linspace(0.03, 0.2, 10)

params_1 = retrieval.eff_parameters(freq_range, sep[0]+0.02, s11_1, s21_1)
params_2 = retrieval.eff_parameters(freq_range, sep[1]+0.02, s11_2, s21_2)
params_3 = retrieval.eff_parameters(freq_range, sep[2]+0.02, s11_3, s21_3)
params_4 = retrieval.eff_parameters(freq_range, sep[3]+0.02, s11_4, s21_4)
params_5 = retrieval.eff_parameters(freq_range, sep[4]+0.02, s11_5, s21_5)
params_6 = retrieval.eff_parameters(freq_range, sep[5]+0.02, s11_6, s21_6)
params_7 = retrieval.eff_parameters(freq_range, sep[6]+0.02, s11_7, s21_7)
params_8 = retrieval.eff_parameters(freq_range, sep[7]+0.02, s11_8, s21_8)
params_9 = retrieval.eff_parameters(freq_range, sep[8]+0.02, s11_9, s21_9)

# %%
np.linspace(0.03, 0.2, 10)
# Out:
# array([0.03      , 0.04888889, 0.06777778, 0.08666667, 0.10555556,
#        0.12444444, 0.14333333, 0.16222222, 0.18111111, 0.2       ])

# %%
freqs = np.linspace(0.3, 0.8, 50)
plt.plot(freq_range*3e8*1e6/1e12, np.real(params['eps']), 'k')
# plt.plot(freq_range*3e8*1e6/1e12, 10*np.real(params['mu']), 'k', linestyle='--')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_1['eps']), 'r')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_2['eps']), 'orange')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_3['eps']), 'yellow')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_4['eps']), 'g')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_5['eps']), 'b')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_6['eps']), 'indigo')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_7['eps']), 'violet')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_8['eps']), 'k')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_9['eps']), 'k', linestyle='--')
# plt.plot(freqs*3e8*1e6/1e12, 10*np.real(params_5['mu']), 'purple')
plt.ylabel('Re($\epsilon$)')
plt.grid()

# %%
plt.plot(freqs*3e8*1e6/1e12, np.real(params_1['eps']), 'k', alpha=1)
plt.plot(freqs*3e8*1e6/1e12, np.real(params_2['eps']), 'k', alpha=0.8)
plt.plot(freqs*3e8*1e6/1e12, np.real(params_3['eps']), 'k', alpha=0.7)
plt.plot(freqs*3e8*1e6/1e12, np.real(params_4['eps']), 'k', alpha=0.6)
plt.plot(freqs*3e8*1e6/1e12, np.real(params_5['eps']), 'k', alpha=0.5)
plt.plot(freqs*3e8*1e6/1e12, np.real(params_6['eps']), 'k', alpha=0.4)
plt.plot(freqs*3e8*1e6/1e12, np.real(params_7['eps']), 'k', alpha=0.3)
plt.plot(freqs*3e8*1e6/1e12, np.real(params_8['eps']), 'k', alpha=0.2)
plt.plot(freqs*3e8*1e6/1e12, np.real(params_9['eps']), 'k', alpha=0.1)
plt.grid()
plt.xlabel('Frequency (THz)')
plt.ylabel('Re($\epsilon$)')
# Out:
# Text(0, 0.5, 'Re($\\epsilon$)')

# %%
plt.plot(freq_range*3e8*1e6/1e12, np.real(params['eps']), 'b', label='Re($\epsilon$)')
plt.plot(freq_range*3e8*1e6/1e12, 10*np.real(params['mu']), 'r', label='10 $\cdot$ Re($\mu$)')

plt.plot(freqs*3e8*1e6/1e12, np.real(params_5['eps']), 'b', linestyle='--')
plt.plot(freqs*3e8*1e6/1e12, 10*np.real(params_5['mu']), 'r', linestyle='--')

plt.plot([],[],'k', label='1 layer')
plt.plot([],[],'k', label='2 layers', linestyle='--')

plt.xlim([0.28*3e8*1e6/1e12, 0.72*3e8*1e6/1e12])
plt.xlabel('Frequency (THz)')
plt.grid()
plt.legend()

# %%
plt.plot(freqs*3e8*1e6/1e12, np.real(params_5['eps']), 'b', label='Re($\epsilon$)')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_5['mu']), 'r', label='Re($\mu$)')
plt.grid()
plt.xlabel('Frequency (THz)')
plt.legend()

# %%
freqs = np.linspace(0.3, 0.8, 50)
plt.plot(freq_range*3e8*1e6/1e12, np.real(params['mu']), 'k')
# plt.plot(freq_range*3e8*1e6/1e12, 10*np.real(params['mu']), 'k', linestyle='--')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_1['mu']), 'r')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_2['mu']), 'orange')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_3['mu']), 'yellow')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_4['mu']), 'g')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_5['mu']), 'b')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_6['mu']), 'indigo')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_7['mu']), 'violet')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_8['mu']), 'k')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_9['mu']), 'k', linestyle='--')
# plt.plot(freqs*3e8*1e6/1e12, 10*np.real(params_5['mu']), 'purple')

plt.ylabel('Re($\mu$)')
plt.grid()

# %% [markdown]
# We see that $\mu$ increases with increasing separation?

# %% [markdown]
# Comparison of the real part of $n$

# %%
freqs = np.linspace(0.3, 0.8, 50)
plt.plot(freq_range*3e8*1e6/1e12, np.real(params['eps'])*np.real(params['mu']), 'k')
# plt.plot(freq_range*3e8*1e6/1e12, 10*np.real(params['mu']), 'k', linestyle='--')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_1['eps'])*np.real(params_1['mu']), 'r')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_2['eps'])*np.real(params_2['mu']), 'orange')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_3['eps'])*np.real(params_3['mu']), 'yellow')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_4['eps'])*np.real(params_4['mu']), 'g')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_5['eps'])*np.real(params_5['mu']), 'b')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_6['eps'])*np.real(params_6['mu']), 'indigo')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_7['eps'])*np.real(params_7['mu']), 'violet')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_8['eps'])*np.real(params_8['mu']), 'k')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_9['eps'])*np.real(params_9['mu']), 'k', linestyle='--')
# plt.plot(freqs*3e8*1e6/1e12, 10*np.real(params_5['mu']), 'purple')

plt.ylabel('n')
plt.grid()

# %%
freqs = np.linspace(0.3, 0.8, 50)
plt.plot(freq_range*3e8*1e6/1e12, np.real(params['n']), 'k')
# plt.plot(freq_range*3e8*1e6/1e12, 10*np.real(params['mu']), 'k', linestyle='--')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_1['n']), 'r')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_2['n']), 'orange')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_3['n']), 'yellow')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_4['n']), 'g')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_5['n']), 'b')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_6['n']), 'indigo')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_7['n']), 'violet')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_8['n']), 'k')
plt.plot(freqs*3e8*1e6/1e12, np.real(params_9['n']), 'k', linestyle='--')
# plt.plot(freqs*3e8*1e6/1e12, 10*np.real(params_5['mu']), 'purple')
plt.ylabel('Re($\epsilon$)')
plt.grid()

# %%
plt.plot(1/freq_range, np.abs(S11)**2, 'k')
plt.plot(1/freq_range, np.abs(S21)**2, 'k', linestyle='--')

plt.plot(1/freqs, np.abs(s11_1)**2, 'r')
plt.plot(1/freqs, np.abs(s21_1)**2, 'r', linestyle='--')
plt.plot(1/freqs, np.abs(s11_2)**2, 'orange')
plt.plot(1/freqs, np.abs(s21_2)**2, 'orange', linestyle='--')
plt.plot(1/freqs, np.abs(s11_3)**2, 'yellow')
plt.plot(1/freqs, np.abs(s21_3)**2, 'yellow', linestyle='--')
plt.plot(1/freqs, np.abs(s11_4)**2, 'g')
plt.plot(1/freqs, np.abs(s21_4)**2, 'g', linestyle='--')
plt.plot(1/freqs, np.abs(s11_5)**2, 'b')
plt.plot(1/freqs, np.abs(s21_5)**2, 'b', linestyle='--')
plt.plot(1/freqs, np.abs(s11_6)**2, 'purple')
plt.plot(1/freqs, np.abs(s21_6)**2, 'purple', linestyle='--')

# %% [markdown]
# There is a wider resonance with more separation

# %% [markdown]
# ---
# Classical SRR case

# %%
plt.plot(freq_range*3e8*1e6/1e12, np.real(params['eps']), 'b', label='Re($\epsilon$)')
plt.plot(freq_range*3e8*1e6/1e12, 10*np.real(params['mu']), 'r', label='10$\cdot$Re($\mu$)')
plt.grid()
plt.legend()
plt.xlabel('Frequency (THz)')
plt.ylabel('Effective parameters')
plt.title('SRR effective parameters')
# Out:
# Text(0.5, 1.0, 'SRR effective parameters')

# %%
plt.plot(freq_range*3e8*1e6/1e12, np.abs(S11)**2, 'b', label='S11')
plt.plot(freq_range*3e8*1e6/1e12, np.abs(S21)**2, 'r', label='S21')

# %% [markdown]
# ---
# 1, 2 and 3 layers with small separation

# %%
s11_2 = np.loadtxt('tmp/E/double_layer1_s11.txt', dtype=np.complex128)
s21_2 = np.loadtxt('tmp/E/double_layer1_s21.txt', dtype=np.complex128)

s11_3 = np.loadtxt('tmp/E/s11_3layers.txt', dtype=np.complex128)
s21_3 = np.loadtxt('tmp/E/s21_3layers.txt', dtype=np.complex128)

s11_4 = np.loadtxt('tmp/E/S11_4_layers.txt', dtype=np.complex128)
s21_4 = np.loadtxt('tmp/E/S21_4_layers.txt', dtype=np.complex128)

s11_5 = np.loadtxt('tmp/E/S11_5_layers.txt', dtype=np.complex128)
s21_5 = np.loadtxt('tmp/E/S21_5_layers.txt', dtype=np.complex128)

s11_6 = np.loadtxt('tmp/E/S11_6_layers.txt', dtype=np.complex128)
s21_6 = np.loadtxt('tmp/E/S21_6_layers.txt', dtype=np.complex128)

freq_range = np.linspace(0.3, 0.7, 50)
params_2 = retrieval.eff_parameters(freq_range, 1*0.05+0.02, s11_2, s21_2)
params_3 = retrieval.eff_parameters(freq_range, 2*0.05+0.02, s11_3, s21_3)
params_4 = retrieval.eff_parameters(freq_range, 3*0.05+0.02, s11_4, s21_4)
params_5 = retrieval.eff_parameters(freq_range, 4*0.05+0.02, s11_5, s21_5)
params_6 = retrieval.eff_parameters(freq_range, 5*0.05+0.02, s11_6, s21_6)

# %%
plt.plot(freq_range*3e8*1e6/1e12, np.real(params['eps']), 'b')
plt.plot(freq_range*3e8*1e6/1e12, np.real(params['mu']), 'r')

plt.plot(freq_range*3e8*1e6/1e12, np.real(params_2['eps']), 'b', linestyle='--')
plt.plot(freq_range*3e8*1e6/1e12, np.real(params_2['mu']), 'r', linestyle='--')

plt.plot(freq_range*3e8*1e6/1e12, np.real(params_3['eps']), 'b', linestyle=':')
plt.plot(freq_range*3e8*1e6/1e12, np.real(params_3['mu']), 'r', linestyle=':')

plt.plot(freq_range*3e8*1e6/1e12, np.real(params_4['eps']), 'b', linestyle='-.')
plt.plot(freq_range*3e8*1e6/1e12, np.real(params_4['mu']), 'r', linestyle='-.')

plt.plot(freq_range*3e8*1e6/1e12, np.real(params_5['eps']), 'b', linestyle='--')
plt.plot(freq_range*3e8*1e6/1e12, np.real(params_5['mu']), 'r', linestyle='--')

plt.plot(freq_range*3e8*1e6/1e12, np.real(params_6['eps']), 'b', linestyle='--')
plt.plot(freq_range*3e8*1e6/1e12, np.real(params_6['mu']), 'r', linestyle='--')

plt.grid()

# %%
# Plot only µ
plt.plot(freq_range*3e8*1e6/1e12, np.real(params['mu']), 'r')
plt.plot(freq_range*3e8*1e6/1e12, np.real(params_2['mu']), 'orange')
plt.plot(freq_range*3e8*1e6/1e12, np.real(params_3['mu']), 'y')
plt.plot(freq_range*3e8*1e6/1e12, np.real(params_4['mu']), 'g')
plt.plot(freq_range*3e8*1e6/1e12, np.real(params_5['mu']), 'b')
plt.plot(freq_range*3e8*1e6/1e12, np.real(params_6['mu']), 'purple')
plt.grid()

# %%
plt.plot(freq_range*3e8*1e6/1e12, np.abs(S11)**2, 'k')
plt.plot(freq_range*3e8*1e6/1e12, np.abs(S21)**2, 'k')

plt.plot(freq_range*3e8*1e6/1e12, np.abs(s11_2)**2, 'r')
plt.plot(freq_range*3e8*1e6/1e12, np.abs(s21_2)**2,'r')

plt.plot(freq_range*3e8*1e6/1e12, np.abs(s11_3)**2, 'b')
plt.plot(freq_range*3e8*1e6/1e12, np.abs(s21_3)**2, 'b')

# plt.plot(freq_range*3e8*1e6/1e12, np.abs(s11_4)**2)

# plt.plot(freq_range*3e8*1e6/1e12, np.abs(s11_5)**2)

# plt.plot(freq_range*3e8*1e6/1e12, np.abs(s11_6)**2, 'r')
# plt.plot(freq_range*3e8*1e6/1e12, np.abs(s21_6)**2, 'r')

# %% [markdown]
# ---
# $\vec H$ polarization

# %%
import meep as mp
import numpy as np
import matplotlib.pyplot as plt
import sys, os

from meep.materials import Ag

import os, sys
sys.path.append('../..')
from meep_metamaterials import metamaterials as mm
from meep_metamaterials.retrieval import retrieval

freq_range = np.linspace(0.3, 0.7, 50)
S11 = np.loadtxt('tmp/H/s11_H.txt', dtype=np.complex128)
S21 = np.loadtxt('tmp/H/s21_H.txt', dtype=np.complex128)
params = retrieval.eff_parameters(freq_range, 0.02, S11, S21)

# %%
plt.plot(freq_range*3e8*1e6/1e12, np.real(params['eps']), 'b', label='Re($\epsilon$)')
plt.plot(freq_range*3e8*1e6/1e12, np.real(params['mu']), 'r', label='Re($\mu$)')
plt.grid()
plt.legend()
plt.xlabel('Frequency (THz)')
plt.ylabel('Effective parameters')
plt.title('SRR effective parameters')
# Out:
# Text(0.5, 1.0, 'SRR effective parameters')

# %% [markdown]
# ---
# Stacked

# %%
import meep as mp
import numpy as np
import matplotlib.pyplot as plt
import sys, os

from meep.materials import Ag

import os, sys
sys.path.append('../..')
from meep_metamaterials import metamaterials as mm
from meep_metamaterials.retrieval import retrieval

# %%
s11_32 = np.loadtxt('tmp/E/s11_stacked3x2.txt', dtype=np.complex128)
s21_32 = np.loadtxt('tmp/E/s21_stacked3x2.txt', dtype=np.complex128)

s11_33 = np.loadtxt('tmp/E/s11_stacked3x3.txt', dtype=np.complex128)
s21_33 = np.loadtxt('tmp/E/s21_stacked3x3.txt', dtype=np.complex128)

s11_23 = np.loadtxt('tmp/E/s11_stacked2x3.txt', dtype=np.complex128)
s21_23 = np.loadtxt('tmp/E/s21_stacked2x3.txt', dtype=np.complex128)

freq_range = np.linspace(0.3, 0.7, 50)
params_32 = retrieval.eff_parameters(freq_range, 0.12+0.45, s11_2, s21_2, plot_branches=True)
params_33 = retrieval.eff_parameters(freq_range, 0.12+0.9, s11_3, s21_3, plot_branches=True, continuity=False, branch=0)
params_23 = retrieval.eff_parameters(freq_range, 0.07+0.9, s11_3, s21_3, plot_branches=True, continuity=False, branch=0)

# %%
plt.plot(freq_range*3e8*1e6/1e12, np.real(params_2['eps']), 'b')
plt.plot(freq_range*3e8*1e6/1e12, np.real(params_2['mu']), 'r')

plt.plot(freq_range*3e8*1e6/1e12, np.real(params_3['eps']), 'b', linestyle='--')
plt.plot(freq_range*3e8*1e6/1e12, np.real(params_3['mu']), 'r', linestyle='--')

plt.grid()

# %%
plt.figure()
plt.subplot(2,2,2)
plt.plot(freq_range*3e8*1e6/1e12, np.real(params_32['eps']), 'b')
plt.plot(freq_range*3e8*1e6/1e12, np.real(params_32['mu']), 'r')
plt.grid()
plt.ylim([-7, 4])
plt.title('3 rings, 2 layers')

plt.subplot(2,2,4)
plt.plot(freq_range*3e8*1e6/1e12, np.real(params_33['eps']), 'b')
plt.plot(freq_range*3e8*1e6/1e12, np.real(params_33['mu']), 'r')
plt.grid()
plt.ylim([-7, 4])
plt.title('3 rings, 3 layers')

plt.subplot(2,2,3)
plt.plot(freq_range*3e8*1e6/1e12, np.real(params_23['eps']), 'b')
plt.plot(freq_range*3e8*1e6/1e12, np.real(params_23['mu']), 'r')
plt.grid()
plt.ylim([-7, 4])
plt.title('2 rings, 3 layers')

plt.show()

# %% [markdown]
# ---

# %%
import meep as mp
import numpy as np
import matplotlib.pyplot as plt
import sys, os

from meep.materials import Ag

import os, sys
sys.path.append('../..')
from meep_metamaterials import metamaterials as mm
from meep_metamaterials.retrieval import retrieval

freq_range = np.linspace(0.3, 0.7, 50)
S11 = np.loadtxt('tmp/E/s11.txt', dtype=np.complex128)
S21 = np.loadtxt('tmp/E/s21.txt', dtype=np.complex128)
params = retrieval.eff_parameters(freq_range, 0.02, S11, S21)
# Out:
# Using MPI version 4.0, 1 processes

# %%
freqs = np.linspace(0.3, 0.8, 50)
s11_subs = np.loadtxt('tmp/E/s11_substrate.txt', dtype=np.complex128)
s21_subs = np.loadtxt('tmp/E/s21_substrate.txt', dtype=np.complex128)
ps = retrieval.eff_parameters(freqs, 0.02, s11_subs, s21_subs, plot_branches=True)
# Out:
# /home/gridsan/mcomella/.conda/envs/pmp/lib/python3.10/site-packages/numpy/core/getlimits.py:500: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/gridsan/mcomella/.conda/envs/pmp/lib/python3.10/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)

# %%
plt.plot(freq_range*3e8*1e6/1e12, np.real(params['eps']), 'b', label='Re($\epsilon$)')
plt.plot(freq_range*3e8*1e6/1e12, np.real(params['mu']), 'r', label='Re($\mu$)')

plt.plot(freqs*3e8*1e6/1e12, np.real(ps['eps']), 'b', linestyle='--')
plt.plot(freqs*3e8*1e6/1e12, np.real(ps['mu']), 'r', linestyle='--')

# %% [markdown]
# ---

# %%
import meep as mp
import numpy as np
import matplotlib.pyplot as plt
import sys, os

from meep.materials import Ag

import os, sys
sys.path.append('../..')
from meep_metamaterials import metamaterials as mm
from meep_metamaterials.retrieval import retrieval

freq_range = np.linspace(0.3, 0.7, 50)
S11 = np.loadtxt('tmp/E/s11.txt', dtype=np.complex128)
S21 = np.loadtxt('tmp/E/s21.txt', dtype=np.complex128)
params = retrieval.eff_parameters(freq_range, 0.02, S11, S21)

# %%
freqs = np.linspace(0.3, 0.8, 50)
s11_2 = np.loadtxt('tmp/E/s11_nested.txt', dtype=np.complex128)
s21_2 = np.loadtxt('tmp/E/s21_nested.txt', dtype=np.complex128)
p2 = retrieval.eff_parameters(freqs, 0.02, s11_2, s21_2, plot_branches=True)

# %%
np.linspace(0.3, 0.8, 50)*3e8*1e6/1e12
# Out:
# array([ 90.        ,  93.06122449,  96.12244898,  99.18367347,
#        102.24489796, 105.30612245, 108.36734694, 111.42857143,
#        114.48979592, 117.55102041, 120.6122449 , 123.67346939,
#        126.73469388, 129.79591837, 132.85714286, 135.91836735,
#        138.97959184, 142.04081633, 145.10204082, 148.16326531,
#        151.2244898 , 154.28571429, 157.34693878, 160.40816327,
#        163.46938776, 166.53061224, 169.59183673, 172.65306122,
#        175.71428571, 178.7755102 , 181.83673469, 184.89795918,
#        187.95918367, 191.02040816, 194.08163265, 197.14285714,
#        200.20408163, 203.26530612, 206.32653061, 209.3877551 ,
#        212.44897959, 215.51020408, 218.57142857, 221.63265306,
#        224.69387755, 227.75510204, 230.81632653, 233.87755102,
#        236.93877551, 240.        ])

# %%
plt.plot(freq_range*3e8*1e6/1e12, np.real(params['eps']), 'b', label='Re($\epsilon$)')
plt.plot(freq_range*3e8*1e6/1e12, np.real(params['mu']), 'r', label='Re($\mu$)')

plt.plot(freqs*3e8*1e6/1e12, np.real(p2['eps']), 'b', linestyle='--')
plt.plot(freqs*3e8*1e6/1e12, np.real(p2['mu']), 'r', linestyle='--')

plt.plot([], [], 'k', label='Normal SRR')
plt.plot([], [], 'k', label='Nested SRR', linestyle='--')

plt.grid()
plt.xlabel('Frequency (THz)')
plt.legend()
